# %% [markdown]
# ## 머신러닝 실습
#
# ### 결정트리 분석
#
# #### 개념
# - if/else 기반으로 규칙을 찾아 학습, 트리 구조의 분류 규칙을 만드는 것
#
# ##### 정보이득지수
# - 엔트로피 개념을 기반으로 함. 엔트로피는 데이터 집합의 혼잡도를 뜻함
#     - 데이터 집합에 다른 데이터가 섞여서 균일도가 떨어지면 혼잡도가 높아진다고 함
#     - 균일도가 높아지면 혼잡도가 낮아진다고 함
# - 정보이득지수는 혼잡도가 줄어들어 얻게 되는 이득 **1-엔트로피**로 계산
#
# ##### 지니계수
# - 데이터의 순도
#     - 지니계수가 높을수록 순도가 낮은 데이터 집합
#     - 지니계수가 0이면 완전 순수한 데이터 집합

# %%
## 필요 라이브러리 사용등록
import pandas as pd
import numpy as np
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# #### 데이터 수집
#
# ##### UC 어바인 ML 연구소 스마트폰 센서데이터
# - 웹사이트에서 다운로드
#     - https://archive.ics.uci.edu/dataset/240/human+activity+recognition+using+smartphones
# - 30명의 연구자원 봉사자가 허리에 갤럭시 S2를 착용하고, 6가지 움직임을 수행, 수집한 XYZ 3축에 대한 데이터
# - 움직인 - WALKING WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING

# %%
## "Human Activity Recognition Using Smartphones" dataset ( id=240) exists in the repository, but is not available for import.
#

# %%
# 피처이름
dfFeatureName = pd.read_csv('./data/features.txt', sep='\s+', header=None, names=['index', 'feature_name'], engine='python')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\3027662982.py:2: SyntaxWarning: invalid escape sequence '\s'
#   dfFeatureName = pd.read_csv('./data/features.txt', sep='\s+', header=None, names=['index', 'feature_name'], engine='python')

# %%
dfFeatureName.tail()
# Out:
#      index                          feature_name
# 556    557      angle(tBodyGyroMean,gravityMean)
# 557    558  angle(tBodyGyroJerkMean,gravityMean)
# 558    559                  angle(X,gravityMean)
# 559    560                  angle(Y,gravityMean)
# 560    561                  angle(Z,gravityMean)

# %%
# index제거, 
featureNames = dfFeatureName.iloc[:,1].values.tolist()

# %%
len(featureNames)
# Out:
# 561

# %%
# X_train, X_test, y_train, y_test 데이터로드
X_train = pd.read_csv('./data/train/X_train.txt', engine='python', sep='\s+', header=None)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\2603796449.py:2: SyntaxWarning: invalid escape sequence '\s'
#   X_train = pd.read_csv('./data/train/X_train.txt', engine='python', sep='\s+', header=None)

# %%
X_test = pd.read_csv('./data/test/X_test.txt', engine='python', sep='\s+', header=None)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\3782832893.py:1: SyntaxWarning: invalid escape sequence '\s'
#   X_test = pd.read_csv('./data/test/X_test.txt', engine='python', sep='\s+', header=None)

# %%
y_train = pd.read_csv('./data/train/y_train.txt', engine='python', sep='\s+', header=None)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\4086435897.py:1: SyntaxWarning: invalid escape sequence '\s'
#   y_train = pd.read_csv('./data/train/y_train.txt', engine='python', sep='\s+', header=None)

# %%
y_test = pd.read_csv('./data/test/y_test.txt', engine='python', sep='\s+', header=None)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\821281185.py:1: SyntaxWarning: invalid escape sequence '\s'
#   y_test = pd.read_csv('./data/test/y_test.txt', engine='python', sep='\s+', header=None)

# %%
# 561개의 컬럼에 이름을 지정
X_train.columns = featureNames

# %%
X_train.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 7347                        -0.070157                        -0.588433
# 7348                         0.165259                        -0.390738
# 7349                         0.195034                         0.025145
# 7350                         0.013865                         0.063907
# 7351                        -0.058402                        -0.387052
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 7347                        -0.880324                    -0.190437
# 7348                        -0.680744                     0.064907
# 7349                        -0.304029                     0.052806
# 7350                        -0.344314                    -0.101360
# 7351                        -0.740738                    -0.280088
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 7347                              0.829718                          0.206972
# 7348                              0.875679                         -0.879033
# 7349                             -0.266724                          0.864404
# 7350                              0.700740                          0.936674
# 7351                             -0.007739                         -0.056088
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 7347                             -0.425619             -0.791883
# 7348                              0.400219             -0.771840
# 7349                              0.701169             -0.779133
# 7350                             -0.589479             -0.785181
# 7351                             -0.616956             -0.783267
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)
# 7347              0.238604              0.049819
# 7348              0.252676              0.050053
# 7349              0.249145              0.040811
# 7350              0.246432              0.025339
# 7351              0.246809              0.036695
#
# [5 rows x 561 columns]

# %%
X_test.columns = featureNames

# %%
X_test.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 2942                         0.074472                        -0.376278
# 2943                         0.101859                        -0.320418
# 2944                        -0.066249                        -0.118854
# 2945                        -0.046467                        -0.205445
# 2946                        -0.010386                        -0.072237
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)
# 2942              0.274627              0.184784
# 2943              0.273578              0.182412
# 2944              0.274479              0.181184
# 2945              0.264782              0.187563
# 2946              0.263936              0.188103
#
# [5 rows x 561 columns]

# %%
y_train.columns = ['action']

# %%
y_train.tail()
# Out:
#       action
# 7347       2
# 7348       2
# 7349       2
# 7350       2
# 7351       2

# %%
y_test.columns = ['action']

# %%
y_test.tail()
# Out:
#       action
# 2942       2
# 2943       2
# 2944       2
# 2945       2
# 2946       2

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((7352, 561), (7352, 1), (2947, 561), (2947, 1))

# %%
## Action의 개수
y_train.value_counts()
# Out:
# action
# 6         1407
# 5         1374
# 4         1286
# 1         1226
# 2         1073
# 3          986
# Name: count, dtype: int64

# %%
labelName = pd.read_csv('./data/activity_labels.txt', engine='python', sep='\s+', header=None).iloc[:, 1].tolist()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13028\3713291607.py:1: SyntaxWarning: invalid escape sequence '\s'
#   labelName = pd.read_csv('./data/activity_labels.txt', engine='python', sep='\s+', header=None).iloc[:, 1].tolist()

# %% [markdown]
# #### 분석모델 구축

# %%
## 결정트리 라이브러리 사용등록
from sklearn.tree import DecisionTreeClassifier

# %%
# 모델생성
model = DecisionTreeClassifier(random_state=40)

# %%
# 모델 훈련
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=40)

# %%
# 예측
y_predict = model.predict(X_test)

# %% [markdown]
# #### 분석지표 확인

# %%
## 분석지표용 라이브러리 사용등록
from sklearn.metrics import accuracy_score

# %%
# 정확도 판단
accuracy_score(y_test, y_predict)
# Out:
# 0.8547675602307431

# %%
## 현재 하이퍼 매개변수 확인
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 40,
#  'splitter': 'best'}

# %% [markdown]
# #### 정확도를 높이기

# %%
## 추가 라이브러리 사용등록
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns

# %%
params = {'max_depth' : [6, 8, 10, 12, 16, 20, 24]}

gridCV = GridSearchCV(model, param_grid=params,scoring='accuracy', cv=5, return_train_score=True)

# %%
gridCV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=40),
#              param_grid={'max_depth': [6, 8, 10, 12, 16, 20, 24]},
#              return_train_score=True, scoring='accuracy')

# %%
dfCVResult = pd.DataFrame(gridCV.cv_results_)
dfCVResult[['param_max_depth', 'mean_test_score', 'mean_train_score']]
# Out:
#   param_max_depth  mean_test_score  mean_train_score
# 0               6         0.848751          0.944879
# 1               8         0.852567          0.982692
# 2              10         0.849440          0.993403
# 3              12         0.847127          0.997212
# 4              16         0.849441          0.999660
# 5              20         0.849169          0.999966
# 6              24         0.849848          1.000000

# %%
## 하이퍼 파라미터를 변경
params = {'max_depth':[8, 10, 16], 'min_samples_split': [2, 20, 24]}
gridCV = GridSearchCV(model, param_grid=params,scoring='accuracy', cv=5, return_train_score=True)

# %%
gridCV.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=40),
#              param_grid={'max_depth': [8, 10, 16],
#                          'min_samples_split': [2, 20, 24]},
#              return_train_score=True, scoring='accuracy')

# %%
dfCVResult = pd.DataFrame(gridCV.cv_results_)
dfCVResult[['param_max_depth', 'param_min_samples_split', 'mean_test_score', 'mean_train_score']]
# Out:
#   param_max_depth param_min_samples_split  mean_test_score  mean_train_score
# 0               8                       2         0.852567          0.982692
# 1               8                      20         0.852838          0.978781
# 2               8                      24         0.851615          0.978237
# 3              10                       2         0.849440          0.993403
# 4              10                      20         0.850801          0.985786
# 5              10                      24         0.857873          0.984256
# 6              16                       2         0.849441          0.999660
# 7              16                      20         0.847127          0.988473
# 8              16                      24         0.849574          0.986738

# %%
gridCV.best_score_
# Out:
# 0.8578731669418277

# %%
gridCV.best_params_
# Out:
# {'max_depth': 10, 'min_samples_split': 24}

# %%
gridCV.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=24, random_state=40)

# %%
## 최고 예측치로 다시 예측
bestModel = gridCV.best_estimator_

# %%
best_y_predict = bestModel.predict(X_test)

# %%
## 정확도
accuracy_score(y_test, best_y_predict)
# Out:
# 0.8663047166610112

# %% [markdown]
# ##### 시각화

# %%
## 독립변수 561개 중 중요도 높은 변수를 찾는 것
len(bestModel.feature_importances_)
# Out:
# 561

# %%
featureImportances = bestModel.feature_importances_

# %%
featureTop10 = pd.Series(featureImportances, index=X_train.columns).sort_values(ascending=False)[:10]

# %%
featureTop10
# Out:
# tGravityAcc-min()-X                0.248497
# fBodyAccJerk-bandsEnergy()-1,16    0.208508
# angle(Y,gravityMean)               0.137694
# fBodyAccMag-energy()               0.113264
# tGravityAcc-arCoeff()-Z,2          0.099601
# fBodyGyro-maxInds-X                0.023511
# tBodyGyro-correlation()-Y,Z        0.016197
# tGravityAcc-energy()-Y             0.016118
# tBodyAccMag-arCoeff()1             0.012370
# tBodyGyro-max()-X                  0.008973
# dtype: float64

# %%
## 바차트
plt.figure(figsize=(15, 5))
plt.title('Smartphone sensor feat Top10')
sns.barplot(x=featureTop10, y=featureTop10.index, hue=featureTop10)
plt.show()

# %% [markdown]
# ##### 결정트리 시각화

# %%
## tree만 다시 사용등록
from sklearn import tree

# %%
print(tree.export_text(bestModel))
# Out:
# |--- feature_52 <= 0.10
# |   |--- class: 6
# |--- feature_52 >  0.10
# |   |--- feature_389 <= -0.97
# |   |   |--- feature_559 <= 0.14
# |   |   |   |--- feature_57 <= -1.00
# |   |   |   |   |--- feature_54 <= 0.06
# |   |   |   |   |   |--- feature_132 <= 0.75
# |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- feature_132 >  0.75
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |--- feature_54 >  0.06
# |   |   |   |   |   |--- feature_169 <= -0.98
# |   |   |   |   |   |   |--- feature_28 <= -0.15
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_28 >  -0.15
# |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- feature_169 >  -0.98
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |--- feature_57 >  -1.00
# |   |   |   |   |--- feature_129 <= -0.87
# |   |   |   |   |   |--- feature_159 <= 0.42
# |   |   |   |   |   |   |--- feature_52 <= 0.99
# |   |   |   |   |   |   |   |--- feature_145 <= -0.69
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_145 >  -0.69
# |   |   |   |   |   |   |   |   |--- feature_196 <= -0.81
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_196 >  -0.81
# |   |   |   |   |   |   |   |   |   |--- feature_376 <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_376 >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |--- feature_52 >  0.99
# |   |   |   |   |   |   |   |--- feature_54 <= 0.07
# |   |   |   |   |   |   |   |   |--- feature_476 <= -1.00
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_476 >  -1.00
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- feature_54 >  0.07
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_159 >  0.42
# |   |   |   |   |   |   |--- feature_52 <= 0.96
# |   |   |   |   |   |   |   |--- feature_301 <= 0.67
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- feature_301 >  0.67
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_52 >  0.96
# |   |   |   |   |   |   |   |--- feature_170 <= -0.99
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_170 >  -0.99
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- feature_129 >  -0.87
# |   |   |   |   |   |--- feature_50 <= 0.07
# |   |   |   |   |   |   |--- feature_443 <= -0.99
# |   |   |   |   |   |   |   |--- feature_354 <= -0.99
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- feature_354 >  -0.99
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_443 >  -0.99
# |   |   |   |   |   |   |   |--- feature_139 <= -0.98
# |   |   |   |   |   |   |   |   |--- feature_180 <= -0.99
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_180 >  -0.99
# |   |   |   |   |   |   |   |   |   |--- feature_390 <= -1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- feature_390 >  -1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |--- feature_139 >  -0.98
# |   |   |   |   |   |   |   |   |--- feature_140 <= -0.92
# |   |   |   |   |   |   |   |   |   |--- feature_132 <= 0.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- feature_132 >  0.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- feature_140 >  -0.92
# |   |   |   |   |   |   |   |   |   |--- feature_464 <= -0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_464 >  -0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_50 >  0.07
# |   |   |   |   |   |   |--- class: 4
# |   |   |--- feature_559 >  0.14
# |   |   |   |--- feature_132 <= 0.85
# |   |   |   |   |--- feature_129 <= -0.89
# |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- feature_129 >  -0.89
# |   |   |   |   |   |--- feature_157 <= 0.66
# |   |   |   |   |   |   |--- feature_101 <= -0.98
# |   |   |   |   |   |   |   |--- feature_149 <= -0.55
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_149 >  -0.55
# |   |   |   |   |   |   |   |   |--- feature_331 <= -1.00
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- feature_331 >  -1.00
# |   |   |   |   |   |   |   |   |   |--- feature_322 <= -1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_322 >  -1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_101 >  -0.98
# |   |   |   |   |   |   |   |--- feature_432 <= -0.98
# |   |   |   |   |   |   |   |   |--- feature_474 <= -1.00
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_474 >  -1.00
# |   |   |   |   |   |   |   |   |   |--- feature_55 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_55 >  0.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_432 >  -0.98
# |   |   |   |   |   |   |   |   |--- feature_373 <= -0.91
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- feature_373 >  -0.91
# |   |   |   |   |   |   |   |   |   |--- feature_129 <= -0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_129 >  -0.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_157 >  0.66
# |   |   |   |   |   |   |--- class: 4
# |   |   |   |--- feature_132 >  0.85
# |   |   |   |   |--- feature_53 <= -0.14
# |   |   |   |   |   |--- feature_409 <= -1.00
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_409 >  -1.00
# |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- feature_53 >  -0.14
# |   |   |   |   |   |--- feature_556 <= -0.45
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_556 >  -0.45
# |   |   |   |   |   |   |--- feature_263 <= -0.21
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_263 >  -0.21
# |   |   |   |   |   |   |   |--- class: 4
# |   |--- feature_389 >  -0.97
# |   |   |--- feature_508 <= -0.52
# |   |   |   |--- feature_74 <= 0.56
# |   |   |   |   |--- feature_448 <= -0.97
# |   |   |   |   |   |--- feature_275 <= -0.30
# |   |   |   |   |   |   |--- feature_37 <= -0.22
# |   |   |   |   |   |   |   |--- feature_558 <= -0.65
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- feature_558 >  -0.65
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_37 >  -0.22
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_275 >  -0.30
# |   |   |   |   |   |   |--- feature_49 <= 0.89
# |   |   |   |   |   |   |   |--- feature_233 <= -0.10
# |   |   |   |   |   |   |   |   |--- feature_241 <= -0.57
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_241 >  -0.57
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_233 >  -0.10
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- feature_49 >  0.89
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- feature_448 >  -0.97
# |   |   |   |   |   |--- feature_209 <= -0.34
# |   |   |   |   |   |   |--- feature_41 <= -0.21
# |   |   |   |   |   |   |   |--- feature_117 <= -0.01
# |   |   |   |   |   |   |   |   |--- feature_298 <= -0.50
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- feature_298 >  -0.50
# |   |   |   |   |   |   |   |   |   |--- feature_333 <= -0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- feature_333 >  -0.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- feature_117 >  -0.01
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_41 >  -0.21
# |   |   |   |   |   |   |   |--- feature_178 <= -0.85
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- feature_178 >  -0.85
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_209 >  -0.34
# |   |   |   |   |   |   |--- feature_37 <= -0.47
# |   |   |   |   |   |   |   |--- feature_282 <= -0.56
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- feature_282 >  -0.56
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_37 >  -0.47
# |   |   |   |   |   |   |   |--- feature_503 <= -0.26
# |   |   |   |   |   |   |   |   |--- feature_559 <= 0.35
# |   |   |   |   |   |   |   |   |   |--- feature_316 <= -0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_316 >  -0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- feature_559 >  0.35
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_503 >  -0.26
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_74 >  0.56
# |   |   |   |   |--- feature_52 <= 0.96
# |   |   |   |   |   |--- feature_57 <= -0.97
# |   |   |   |   |   |   |--- feature_66 <= 0.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_66 >  0.75
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_57 >  -0.97
# |   |   |   |   |   |   |--- feature_71 <= -0.31
# |   |   |   |   |   |   |   |--- feature_9 <= -0.36
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  -0.36
# |   |   |   |   |   |   |   |   |--- feature_461 <= -0.54
# |   |   |   |   |   |   |   |   |   |--- feature_196 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- feature_196 >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- feature_461 >  -0.54
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_71 >  -0.31
# |   |   |   |   |   |   |   |--- feature_117 <= -0.00
# |   |   |   |   |   |   |   |   |--- feature_450 <= -0.69
# |   |   |   |   |   |   |   |   |   |--- feature_143 <= -0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_143 >  -0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- feature_450 >  -0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_117 >  -0.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_52 >  0.96
# |   |   |   |   |   |--- feature_222 <= -0.29
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_222 >  -0.29
# |   |   |   |   |   |   |--- feature_537 <= -0.97
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |--- feature_537 >  -0.97
# |   |   |   |   |   |   |   |--- feature_291 <= -0.97
# |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |--- feature_291 >  -0.97
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_508 >  -0.52
# |   |   |   |--- feature_159 <= 0.28
# |   |   |   |   |--- feature_67 <= -0.44
# |   |   |   |   |   |--- feature_418 <= -0.96
# |   |   |   |   |   |   |--- feature_302 <= -0.39
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_302 >  -0.39
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_418 >  -0.96
# |   |   |   |   |   |   |--- feature_89 <= -0.51
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_89 >  -0.51
# |   |   |   |   |   |   |   |--- feature_9 <= 0.05
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_9 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_412 <= -0.98
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- feature_412 >  -0.98
# |   |   |   |   |   |   |   |   |   |--- feature_53 <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |   |--- feature_53 >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- feature_67 >  -0.44
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_159 >  0.28
# |   |   |   |   |--- feature_393 <= -0.47
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_393 >  -0.47
# |   |   |   |   |   |--- class: 3

# %%
fig = plt.figure(figsize=(15, 8))

_ = tree.plot_tree(bestModel)

plt.show()

# %% [markdown]
# ##### Graphviz 패키지 설치
# - Add Path for all user를 체크 후 설치

# %%
## Graphviz 모듈을 설치
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ----------------- ---------------------- 20.5/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB 801.9 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
## graphviz와 scikit-learn연결
from sklearn.tree import export_graphviz

# %%
export_graphviz(bestModel, out_file='tree.dot', class_names=labelName, feature_names=featureNames, impurity=True, filled=True)

# %%
## graphviz모듈 사용등록
## graphviz는 설치 후 안되는 경우가 종종 발생
import graphviz

# %%
with open('./tree.dot')as f:
    dot_graph = f.read()
    
graphviz.Sourse(dot_graph)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 4
#       1 with open('./tree.dot')as f:
#       2     dot_graph = f.read()
# ----> 4 graphviz.Sourse(dot_graph)
#       5 plt.show()
#
# AttributeError: module 'graphviz' has no attribute 'Sourse'
