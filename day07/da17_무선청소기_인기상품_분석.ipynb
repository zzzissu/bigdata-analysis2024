# %% [markdown]
# ## 빅데이터 실습
#
# ### 다나와 무선청소기 상품분석
#
# #### 데이터 수집
#
# ##### 셀레니움 사용
# - 무선청소기 검색에 사용할 URL
#     https://search.danawa.com/dsearch.php?query=무선청소기&originalQuery=무선청소기&previousKeyword=무선청소기&checkedInfo=N&volumeType=allvs&page=1&limit=120&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&mode=simple&isInitTireSmartFinder=N&recommendedSort=N&defaultUICategoryCode=10325109&defaultPhysicsCategoryCode=72%7C80%7C81%7C0&defaultVmTab=3138&defaultVaTab=1098867&isZeroPrice=Y&quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A
#     - URL 최소화 링크
#     https://search.danawa.com/dsearch.php?query=무선청소기&page=2&limit=120&sort=saveDESC&list=list
#     한페이지가 다 로드될때 5초정도의 시간이 필요

# %%
## 필수 라이브러리 사용등록
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from urllib import parse    # url encode
from tqdm import tqdm
import time

# %%
## 웹드라이버로 크롬 오픈
driver = webdriver.Chrome()
url = r'https://search.danawa.com/dsearch.php?query=무선청소기&page=1&limit=120&sort=saveDESC&list=list'
driver.get(url)
time.sleep(0.5)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select('li.prod_item')
# Out:
# [<li class="prod_item" id="productItem19965230">
#  <input id="productItem_categoryInfo_19965230" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_19965230" type="hidden" value="890820"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=19965230&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_19965230" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="코드제로 A9S AX9884" fetchpriority="high" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/230/965/img/19965230_1.jpg?shrink=130:130&amp;_v=20240311100128"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_19965230" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  <input id="hidden_cate_sub_c1" type="hidden" value="72"/>
#  <input id="hidden_cate_sub_c2" type="hidden" value="80"/>
#  <input id="hidden_cate_sub_c3" type="hidden" value="81"/>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=19965230&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965230',1);" target="_blank">LG전자 오브제컬렉션 코드제로 A9S AX9884</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">가장 프리미엄 라인업(AX)으로 스팀물걸레 포함 구성, AX9988보다 흡입력만 낮음</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(232536, 'view', this, 0, 72, 80); return false;">흡입+물걸레(동시)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(3996, 'view', this, 0, 72, 80); return false;">흡입력</a>: 												250W / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230403, 'view', this, 0, 72, 80); return false;">소비전력</a>: 												620W / 2023년형 / <br/><span class="cm_mark">[구성]</span> 거치대: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(218112, 'view', this, 0, 72, 80); return false;">올인원타워</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(219165, 'view', this, 0, 72, 80); return false;">먼지비움</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230880, 'view', this, 0, 72, 80); return false;">충전</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230874, 'view', this, 0, 72, 80); return false;">UVC LED</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(232551, 'view', this, 0, 72, 80); return false;">액서서리수납</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">스탠드거치</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">먼지비움시간</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">30초</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(225510, 'view', this, 0, 72, 80); return false;">와이드바닥</a> / 												물걸레: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(224673, 'view', this, 0, 72, 80); return false;">스팀</a>, 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230919, 'view', this, 0, 72, 80); return false;">고온</a>, 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(9440, 'view', this, 0, 72, 80); return false;">일반</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18442, 'view', this, 0, 72, 80); return false;">솔형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">먼지봉투</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">2.5L</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(8515, 'view', this, 0, 72, 80); return false;">사용시간</a>: 												30분(최대) / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												4시간 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(2개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27314, 'view', this, 0, 72, 80); return false;">리튬이온</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(213565, 'view', this, 0, 72, 80); return false;">25.2V</a> / 												<br/><span class="cm_mark">[청소]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(4000, 'view', this, 0, 72, 80); return false;">싸이클론흡입</a> / 																									 ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_19965230"></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="https://plan.danawa.com/info/?nPlanSeq=8742" rel="noopener" target="_blank">LG 무선청소기 생긴건 비슷한데
#  가격이 다른 이유</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2023.04.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:97%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=19965230&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>371</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <a class="brand-log" href="http://brand.danawa.com/lge" rel="noopener" target="_blank" title="해당상품 브랜드로그 보러가기">브랜드로그</a>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="19965230" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965230',4);" price="890820" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_19965230" type="hidden" value="카밍그린, AX9884GE^19965152**카밍베이지, AX9884WE^19965230**에센스그라파이트, AX9884TE^19965206//LG전자 오브제컬렉션 코드제로 A9S AX9884//19965230"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965230',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li id="productInfoDetail_19965152" style="">
#  <div class="box__vs-tooltip" style="display: block;">
#  <div class="box__contents">
#  <em>VS검색</em> 담고 <em>스펙 비교하기</em>
#  </div>
#  <button class="button__close" id="vsSearchTooltip" type="button">
#  <span class="blind">닫기</span>
#  </button>
#  </div>
#  <p class="chk_sect">
#  													552몰
#  													<label for="prodCompareCheck_19965152">
#  <input id="prodCompareCheck_19965152" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="19965152"/>
#  <input name="compareRepValue" type="hidden" value="19965230"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=19965152&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965152',1);" target="_blank"><strong>877,800</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_19965152"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  																																								카밍그린, AX9884GE																										<a href="https://prod.danawa.com/info/?pcode=19965152&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965152',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li class="rank_one" id="productInfoDetail_19965230" style="">
#  <p class="chk_sect">
#  													684몰
#  													<label for="prodCompareCheck_19965230">
#  <input id="prodCompareCheck_19965230" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="19965230"/>
#  <input name="compareRepValue" type="hidden" value="19965230"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=19965230&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965230',1);" target="_blank"><strong>890,820</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_19965230"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">1위</span>																											카밍베이지, AX9884WE																										<a href="https://prod.danawa.com/info/?pcode=19965230&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965230',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_19965206" style="">
#  <p class="chk_sect">
#  													540몰
#  													<label for="prodCompareCheck_19965206">
#  <input id="prodCompareCheck_19965206" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="19965206"/>
#  <input name="compareRepValue" type="hidden" value="19965230"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=19965206&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965206',1);" target="_blank"><strong>833,260</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_19965206"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">2위</span>																											에센스그라파이트, AX9884TE																										<a href="https://prod.danawa.com/info/?pcode=19965206&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','19965206',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem16422554">
#  <input id="productItem_categoryInfo_16422554" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_16422554" type="hidden" value="445230"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=16422554&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_16422554" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="제트 VS20B956AX" fetchpriority="high" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/554/422/img/16422554_1.jpg?shrink=130:130&amp;_v=20240318160957"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_16422554" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=16422554&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422554',1);" target="_blank">삼성전자 비스포크 제트 VS20B956AX</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">청정스테이션이 탑재된 제품 중 가장 저렴! (물걸레 미포함)</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230862, 'view', this, 0, 72, 80); return false;">흡입형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(3996, 'view', this, 0, 72, 80); return false;">흡입력</a>: 												220W / 2022년형 / <br/><span class="cm_mark">[구성]</span> 거치대: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(218109, 'view', this, 0, 72, 80); return false;">청정스테이션</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(219165, 'view', this, 0, 72, 80); return false;">먼지비움</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230880, 'view', this, 0, 72, 80); return false;">충전</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230874, 'view', this, 0, 72, 80); return false;">UVC LED</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">스탠드거치</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">먼지비움시간</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">14초</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(18333, 'view', this, 0, 72, 80); return false;">바닥</a> / 												물걸레: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230928, 'view', this, 0, 72, 80); return false;">별매</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18442, 'view', this, 0, 72, 80); return false;">솔형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27313, 'view', this, 0, 72, 80); return false;">연장관</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">먼지봉투</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">1.2L</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(8515, 'view', this, 0, 72, 80); return false;">사용시간</a>: 												1시간(최대) / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												3시간30분 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(1개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27314, 'view', this, 0, 72, 80); return false;">리튬이온</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(214659, 'view', this, 0, 72, 80); return false;">2200mAh</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(213565, 'view', this, 0, 72, 80); return false;">25.2V</a> / 												<br/><span class="cm_mark">[청소]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(4000, 'view', this, 0, 72, 80); return false;">싸이클론흡입</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27323, 'view', this, 0, 72, 80); return false;">LED라이트</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27442, 'view', this, 0, 72, 80); return false;">디지털인버터모터</a> / 																											 ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_16422554"></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="https://plan.danawa.com/info/?nPlanSeq=9303" rel="noopener" target="_blank">빨리 받고 싶은 가전제품
#  이제 하루면 와요!</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2022.02.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:97%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=16422554&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>1,752</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="16422554" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422554',4);" price="445230" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_16422554" type="hidden" value="산토리니베이지, VS20B956AXE^16422536**페블그레이, VS20B956AXG^16422554**리퍼/중고^29311778//삼성전자 비스포크 제트 VS20B956AX//16422554"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422554',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li id="productInfoDetail_16422536" style="">
#  <p class="chk_sect">
#  													354몰
#  													<label for="prodCompareCheck_16422536">
#  <input id="prodCompareCheck_16422536" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="16422536"/>
#  <input name="compareRepValue" type="hidden" value="16422554"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=16422536&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422536',1);" target="_blank"><strong>451,570</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_16422536"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">2위</span>																											산토리니베이지, VS20B956AXE																										<a href="https://prod.danawa.com/info/?pcode=16422536&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422536',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li class="rank_one" id="productInfoDetail_16422554" style="">
#  <p class="chk_sect">
#  													333몰
#  													<label for="prodCompareCheck_16422554">
#  <input id="prodCompareCheck_16422554" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="16422554"/>
#  <input name="compareRepValue" type="hidden" value="16422554"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=16422554&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422554',1);" target="_blank"><strong>445,230</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_16422554"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">1위</span>																											페블그레이, VS20B956AXG																										<a href="https://prod.danawa.com/info/?pcode=16422554&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','16422554',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_29311778" style="">
#  <p class="chk_sect">
#  													0몰
#  													<label for="prodCompareCheck_29311778">
#  <input id="prodCompareCheck_29311778" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="29311778"/>
#  <input name="compareRepValue" type="hidden" value="16422554"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=29311778&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','29311778',1);" target="_blank"><strong class="no_sale">일시품절</strong></a>
#  </p>
#  <p class="memory_sect">
#  																																								리퍼/중고																										<a href="https://prod.danawa.com/info/?pcode=29311778&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','29311778',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem18868094">
#  <input id="productItem_categoryInfo_18868094" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_18868094" type="hidden" value="151050"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=18868094&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_18868094" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="M22" fetchpriority="high" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/094/868/img/18868094_1.jpg?shrink=130:130&amp;_v=20240311131953"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_18868094" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=18868094&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','18868094',1);" target="_blank">샤오미 미홀 M22</a>
#  </p>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230862, 'view', this, 0, 72, 80); return false;">흡입형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230403, 'view', this, 0, 72, 80); return false;">소비전력</a>: 												320W / 2023년형 / <br/><span class="cm_mark">[구성]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">벽걸이거치</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(18333, 'view', this, 0, 72, 80); return false;">바닥</a> / 												물걸레: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230928, 'view', this, 0, 72, 80); return false;">별매</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18453, 'view', this, 0, 72, 80); return false;">침구</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18442, 'view', this, 0, 72, 80); return false;">솔형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												5시간 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(1개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(214659, 'view', this, 0, 72, 80); return false;">2600mAh</a> / 												<br/><span class="cm_mark">[청소]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(27323, 'view', this, 0, 72, 80); return false;">LED라이트</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(31525, 'view', this, 0, 72, 80); return false;">BLDC모터</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(214653, 'view', this, 0, 72, 80); return false;">먼지통</a>: 												0.6L / <br/><span class="cm_mark">[부가]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(230949, 'view', this, 0, 72, 80); return false;">워셔블헤파필터</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27312, 'view', this, 0, 72, 80); return false;">무게</a>: 												1.5kg / 크기(가로x세로x깊이): 240x1040x204mm											</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_18868094"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2023.01.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:98%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.9</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=18868094&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>999</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="18868094" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','18868094',4);" price="151050" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_18868094" type="hidden" value="//샤오미 미홀 M22"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','18868094',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_18868094">
#  <p class="chk_sect">
#  													36몰
#  																											<label for="prodCompareCheck_18868094">
#  <input id="prodCompareCheck_18868094" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="18868094"/>
#  <input name="compareRepValue" type="hidden" value="18868094"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=18868094&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','18868094',1);; _trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>151,050</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_18868094"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  																													본체																												<a class="" href="https://prod.danawa.com/info/?pcode=18868094&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','18868094',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem20058890">
#  <input id="productItem_categoryInfo_20058890" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_20058890" type="hidden" value="715560"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=20058890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_20058890" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="코드제로 A9S AX9604" fetchpriority="high" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/prod_img/500000/890/058/img/20058890_1.jpg?shrink=130:130&amp;_v=20240311094901"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_20058890" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=20058890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20058890',1);" target="_blank">LG전자 오브제컬렉션 코드제로 A9S AX9604</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">모델명 차이: 구성의 차이 / 물걸레, 침구 브러쉬 구성이 없는 실속형</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230862, 'view', this, 0, 72, 80); return false;">흡입형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(3996, 'view', this, 0, 72, 80); return false;">흡입력</a>: 												250W / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230403, 'view', this, 0, 72, 80); return false;">소비전력</a>: 												620W / 2023년형 / <br/><span class="cm_mark">[구성]</span> 거치대: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(218112, 'view', this, 0, 72, 80); return false;">올인원타워</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(219165, 'view', this, 0, 72, 80); return false;">먼지비움</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230880, 'view', this, 0, 72, 80); return false;">충전</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230874, 'view', this, 0, 72, 80); return false;">UVC LED</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(232551, 'view', this, 0, 72, 80); return false;">액서서리수납</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">스탠드거치</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">먼지비움시간</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">30초</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(225510, 'view', this, 0, 72, 80); return false;">와이드바닥</a> / 												물걸레: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230928, 'view', this, 0, 72, 80); return false;">별매</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18442, 'view', this, 0, 72, 80); return false;">솔형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">먼지봉투</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">2.5L</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(8515, 'view', this, 0, 72, 80); return false;">사용시간</a>: 												30분(최대) / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												4시간 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(1개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27314, 'view', this, 0, 72, 80); return false;">리튬이온</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(213565, 'view', this, 0, 72, 80); return false;">25.2V</a> / 												<br/><span class="cm_mark">[청소]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(4000, 'view', this, 0, 72, 80); return false;">싸이클론흡입</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27323, 'view', this, 0, 72, 80); return false;">LED라이트</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27442, 'view', this, 0, 72, 80); return false;">스마트인버터모터</a> / 												<br/><sp ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_20058890"></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_special">
#  <dt>특가정보</dt>
#  <dd>
#  <a class="click_log_prod_sp_info" href="http://www.ssg.com/item/itemView.ssg?itemId=1000573937972&amp;siteNo=6001&amp;salestrNo=6005&amp;ckwhere=ssg_danawa&amp;appPopYn=n&amp;utm_medium=PCS&amp;utm_source=danawa&amp;utm_campaign=danawa_pcs" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" rel="noopener" target="_blank"><strong>679,616</strong>원 SSG 추가할인</a>
#  </dd>
#  </dl>
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="https://plan.danawa.com/info/?nPlanSeq=8742" rel="noopener" target="_blank">LG 무선청소기 생긴건 비슷한데
#  가격이 다른 이유</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2023.04.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:98%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=20058890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>185</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <a class="brand-log" href="http://brand.danawa.com/lge" rel="noopener" target="_blank" title="해당상품 브랜드로그 보러가기">브랜드로그</a>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="20058890" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20058890',4);" price="715560" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_20058890" type="hidden" value="//LG전자 오브제컬렉션 코드제로 A9S AX9604"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20058890',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_20058890">
#  <p class="chk_sect">
#  													433몰
#  																											<label for="prodCompareCheck_20058890">
#  <input id="prodCompareCheck_20058890" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="20058890"/>
#  <input name="compareRepValue" type="hidden" value="20058890"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=20058890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20058890',1);; _trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>715,560</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_20058890"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  																													카밍베이지, AX9604WE																												<a class="" href="https://prod.danawa.com/info/?pcode=20058890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20058890',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem20361974">
#  <input id="productItem_categoryInfo_20361974" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_20361974" type="hidden" value="1229240"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=20361974&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_20361974" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="코드제로 A9S AX9988" class="lazyload" data-expand="700" data-src="//img.danawa.com/prod_img/500000/974/361/img/20361974_1.jpg?shrink=130:130&amp;_v=20240311095156" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/new/noData/img/noImg_160.gif"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_20361974" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=20361974&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20361974',1);" target="_blank">LG전자 오브제컬렉션 코드제로 A9S AX9988</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">23년형 중에서도 가장 흡입력이 강하고 모든 구성이 포함인 제품</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(232536, 'view', this, 0, 72, 80); return false;">흡입+물걸레(동시)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(3996, 'view', this, 0, 72, 80); return false;">흡입력</a>: 												280W / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230403, 'view', this, 0, 72, 80); return false;">소비전력</a>: 												677W / 2023년형 / <br/><span class="cm_mark">[구성]</span> 거치대: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(218112, 'view', this, 0, 72, 80); return false;">올인원타워</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(219165, 'view', this, 0, 72, 80); return false;">먼지비움</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230880, 'view', this, 0, 72, 80); return false;">충전</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230874, 'view', this, 0, 72, 80); return false;">UVC LED</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(232551, 'view', this, 0, 72, 80); return false;">액서서리수납</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">스탠드거치</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">먼지비움시간</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230889, 'view', this, 0, 72, 80); return false;">30초</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(225510, 'view', this, 0, 72, 80); return false;">와이드바닥</a> / 												물걸레: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(224673, 'view', this, 0, 72, 80); return false;">스팀</a>, 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230919, 'view', this, 0, 72, 80); return false;">고온</a>, 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(9440, 'view', this, 0, 72, 80); return false;">일반</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18453, 'view', this, 0, 72, 80); return false;">침구</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18442, 'view', this, 0, 72, 80); return false;">솔형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">먼지봉투</a>: 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14818, 'view', this, 0, 72, 80); return false;">2.5L</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(8515, 'view', this, 0, 72, 80); return false;">사용시간</a>: 												1시간(최대) / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												4시간 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(2개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27314, 'view', this, 0, 72, 80); return false;">리튬이온</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(213565, 'view', this, 0, 72, 80); return false;">25.2V</a> / 												<br/><span class="cm_mark">[청소]</span> < ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_20361974"></div>
#  <div class="prod_rel_content">
#  <dl class="rel_item rel_event">
#  <dt>기획전</dt>
#  <dd><a href="https://plan.danawa.com/info/?nPlanSeq=8742" rel="noopener" target="_blank">LG 무선청소기 생긴건 비슷한데
#  가격이 다른 이유</a></dd>
#  </dl>
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2023.05.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:96%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=20361974&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>185</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <a class="brand-log" href="http://brand.danawa.com/lge" rel="noopener" target="_blank" title="해당상품 브랜드로그 보러가기">브랜드로그</a>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="20361974" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20361974',4);" price="1229240" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_20361974" type="hidden" value="//LG전자 오브제컬렉션 코드제로 A9S AX9988"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20361974',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
# ...
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_14374490"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2021.06.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:93%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.6</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=14374490&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>118</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="14374490" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','14374490',4);" price="368430" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_14374490" type="hidden" value="//삼성전자 비스포크 슬림 VS15A680DFW"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','14374490',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_14374490">
#  <p class="chk_sect">
#  													171몰
#  																											<label for="prodCompareCheck_14374490">
#  <input id="prodCompareCheck_14374490" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="14374490"/>
#  <input name="compareRepValue" type="hidden" value="14374490"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=14374490&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','14374490',1);; _trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>368,430</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_14374490"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <a class="" href="https://prod.danawa.com/info/?pcode=14374490&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','14374490',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>,
#  <li class="prod_item" id="productItem20295149">
#  <input id="productItem_categoryInfo_20295149" type="hidden" value="생활가전_청소기"/>
#  <input id="min_price_20295149" type="hidden" value="960300"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link click_log_product_standard_img_" href="https://prod.danawa.com/info/?pcode=20295149&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" id="thumbLink_20295149" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="Gen5 디텍트 컴플리트" class="lazyload" data-expand="700" data-src="//img.danawa.com/prod_img/500000/149/295/img/20295149_1.jpg?shrink=130:130&amp;_v=20231026124801" onerror="this.onerror=null; this.src='//img.danawa.com/new/noData/img/noImg_160.gif';" src="//img.danawa.com/new/noData/img/noImg_160.gif"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_20295149" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  										</a>
#  </div>
#  <div class="prod_info">
#  <p class="prod_name">
#  <a class="click_log_product_standard_title_" href="https://prod.danawa.com/info/?pcode=20295149&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="_trkEventLog('통합검색_상품블로그_유입'); doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20295149',1);" target="_blank">다이슨 Gen5 디텍트 컴플리트</a>
#  </p>
#  <div class="prod_intro">
#  <p class="intro_text">퍼플/퍼플: 구성품7개, 블루/코퍼: 구성품10개</p>
#  </div>
#  <dl class="prod_spec_set">
#  <dt class="screen_out">상세 스펙</dt>
#  <dd>
#  <div class="spec_list">
#  <a class="view_dic" href="#" onclick="$.termDicViewLink(8501, 'view', this, 0, 72, 80); return false;">핸디스틱<b>청소기</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14900, 'view', this, 0, 72, 80); return false;"><b>무선</b></a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230862, 'view', this, 0, 72, 80); return false;">흡입형</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(3996, 'view', this, 0, 72, 80); return false;">흡입력</a>: 												262AW / 2022년형 / <br/><span class="cm_mark">[구성]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(230883, 'view', this, 0, 72, 80); return false;">스탠드거치</a> / 												브러쉬: 															<a class="view_dic" href="#" onclick="$.termDicViewLink(230904, 'view', this, 0, 72, 80); return false;">레이저바닥</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(212077, 'view', this, 0, 72, 80); return false;">펫</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(18436, 'view', this, 0, 72, 80); return false;">틈새</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230898, 'view', this, 0, 72, 80); return false;">미니바닥</a> / 												<br/><span class="cm_mark">[배터리]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(8515, 'view', this, 0, 72, 80); return false;">사용시간</a>: 												1시간10분(최대) / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(14921, 'view', this, 0, 72, 80); return false;">충전시간</a>: 												4시간30 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(217578, 'view', this, 0, 72, 80); return false;">분리형(1개)</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(27314, 'view', this, 0, 72, 80); return false;">리튬이온</a> / 												<br/><span class="cm_mark">[청소]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(4000, 'view', this, 0, 72, 80); return false;">싸이클론흡입</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(211225, 'view', this, 0, 72, 80); return false;">먼지감지센서</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(214653, 'view', this, 0, 72, 80); return false;">먼지통</a>: 												0.77L / <br/><span class="cm_mark">[부가]</span> <a class="view_dic" href="#" onclick="$.termDicViewLink(30484, 'view', this, 0, 72, 80); return false;">디스플레이표시</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(230949, 'view', this, 0, 72, 80); return false;">워셔블헤파필터</a> / 																											<a class="view_dic" href="#" onclick="$.termDicViewLink(14771, 'view', this, 0, 72, 80); return false;">색상</a>: 												퍼플/퍼플 / 															<a class="view_dic" href="#" onclick="$.termDicViewLink(27312, 'view', this, 0, 72, 80); return false;">무게</a>: 												3.5kg / 크기(가로x세로x깊이): 276x1276x250mm											</div>
#  </dd>
#  </dl>
#  <div class="relation_goods_unit" id="relation_goods_unit_20295149"></div>
#  <div class="prod_rel_content">
#  </div>
#  <div class="prod_sub_info">
#  <div class="prod_sub_meta">
#  <dl class="meta_item mt_date">
#  <dt>등록월</dt>
#  <dd>2022.09.</dd>
#  </dl>
#  <dl class="meta_item mt_comment">
#  <dt><span class="dt_behind">상품의견</span></dt>
#  <dd>
#  <div class="cnt_star">
#  <div class="point_type_list">
#  <div class="mask" style="width:97%">
#  </div>
#  </div>
#  <div class="point_num">
#  <strong>4.8</strong>점
#  																	</div>
#  </div>
#  <div class="cnt_opinion">
#  																	(<a class="click_log_prod_content_count" href="https://prod.danawa.com/info/?pcode=20295149&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109&amp;bookmark=cm_opinion#bookmark_cm_opinion" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank"><strong>61</strong></a>건)
#  																</div>
#  </dd>
#  </dl>
#  <dl class="meta_item">
#  <dt class="screen_out">관심상품</dt>
#  <dd>
#  <a class="click_wish_prod click_log_wishList btn_like" code="20295149" href="#" key="" listtype="" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20295149',4);" price="960300" title="관심상품에 담기">관심
#  														</a>
#  </dd>
#  <input id="wishListBundleVal_20295149" type="hidden" value="퍼플/퍼플^20295149**블루/코퍼^17886890**리퍼/중고^20464391//다이슨 Gen5 디텍트 컴플리트//20295149"/>
#  </dl>
#  </div>
#  <dl class="prod_category_location">
#  <dt class="screen_out">상품분류</dt>
#  <dd>
#  <a href="https://prod.danawa.com/list/?cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20295149',3);" target="_blank"><span>생활가전</span> &gt; <span>청소기</span> &gt; <span>무선청소기</span></a> <div class="more_cate_layer" style="display: none; z-index: 1;">
#  <ul class="list_category_location">
#  </ul>
#  </div>
#  </dd>
#  </dl>
#  </div>
#  </div>
#  <div class="prod_pricelist" data-cate="72|80|81|0">
#  <ul>
#  <li class="rank_one" id="productInfoDetail_20295149" style="">
#  <p class="chk_sect">
#  													184몰
#  													<label for="prodCompareCheck_20295149">
#  <input id="prodCompareCheck_20295149" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="20295149"/>
#  <input name="compareRepValue" type="hidden" value="20295149"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=20295149&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20295149',1);" target="_blank"><strong>960,300</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_20295149"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">1위</span>																											퍼플/퍼플																										<a href="https://prod.danawa.com/info/?pcode=20295149&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20295149',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_17886890" style="">
#  <p class="chk_sect">
#  													65몰
#  													<label for="prodCompareCheck_17886890">
#  <input id="prodCompareCheck_17886890" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="17886890"/>
#  <input name="compareRepValue" type="hidden" value="20295149"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=17886890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','17886890',1);" target="_blank"><strong>1,117,500</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_17886890"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  <span class="rank">2위</span>																											블루/코퍼																										<a href="https://prod.danawa.com/info/?pcode=17886890&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','17886890',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  <li id="productInfoDetail_20464391" style="">
#  <p class="chk_sect">
#  													2몰
#  													<label for="prodCompareCheck_20464391">
#  <input id="prodCompareCheck_20464391" type="checkbox"/><strong>VS검색</strong>
#  </label>
#  <input name="compareValue" type="hidden" value="20464391"/>
#  <input name="compareRepValue" type="hidden" value="20295149"/>
#  </p>
#  <p class="price_sect">
#  <a class="click_log_product_standard_price_" href="https://prod.danawa.com/info/?pcode=20464391&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20464391',1);" target="_blank"><strong>884,520</strong>원</a>
#  <span class="more_btn_wrap">
#  <button class="ico i_more" data-producttype="standard">가격정보 더보기</button>
#  <span class="layer_price_more" id="layer_price_more_20464391"></span>
#  <span class="sep_line"></span>
#  </span>
#  </p>
#  <p class="memory_sect">
#  																																								리퍼/중고																										<a href="https://prod.danawa.com/info/?pcode=20464391&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=10325109" onmousedown="doCTR('%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0','20464391',1);" target="_blank">
#  </a>
#  </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </li>]

# %%
prodItems = soup.select('ul.product_list > li.prod_item')

# %%
# id="productItem19965230" 식으로 전개되므로 productItem이 아니면 패스
# 제품명 가져오기, 만약 애드스마트 영역이면 예외발생
prodItems[0].select('p.prod_name > a')[0].text.split()
# Out:
# ['LG전자', '오브제컬렉션', '코드제로', 'A9S', 'AX9884']

# %%
# 제품스펙 가져오기
prodItems[0].select('div.spec_list')[0].text.strip().replace('\t', '')
# Out:
# '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm'

# %%
# 제품가격 가져오기
# 책에서는 1위 데이터를 가져오도록 했음
# 우리는 input 중 두번째 값이 최소값을 담고 있는 것을 확인
prodItems[0].select('input')[1].get('value')
# Out:
# '890820'

# %%
# 제품 인트로
prodItems[0].select('p.intro_text')[0].text
# Out:
# '가장 프리미엄 라인업(AX)으로 스팀물걸레 포함 구성, AX9988보다 흡입력만 낮음'

# %% [markdown]
# #### 1번 페이지에서 상품정보 추출

# %%
prodData = []

for prodItem in prodItems:
    try:
        prodName = prodItem.select('p.prod_name > a')[0].text.strip()   # 상품명 가져오기
        specList = prodItem.select('div.spec_list')[0].text.strip().replace('\t', '')   # 상품 스팩목록 가져오기
        price = prodItem.select('input')[1].get('value') # 최저가 가져오기
        prodData.append([prodName, specList, price])
    except:
        pass

# %%
# 결과확인
prodData
# Out:
# [['LG전자 오브제컬렉션 코드제로 A9S AX9884',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '890820'],
#  ['삼성전자 비스포크 제트 VS20B956AX',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / 2022년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 페블그레이 / 크기(가로x세로x깊이): 250x930x202mm',
#   '445230'],
#  ['샤오미 미홀 M22',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 320W / 2023년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / [배터리] 충전시간: 5시간 / 분리형(1개) / 2600mAh / [청소] LED라이트 / BLDC모터 / 먼지통: 0.6L / [부가] 워셔블헤파필터 / 무게: 1.5kg / 크기(가로x세로x깊이): 240x1040x204mm',
#   '151050'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9604',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '715560'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9988',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 280W / 소비전력: 677W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '1229240'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9202WD',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 디스플레이표시 / 배터리잔량표시 / 헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '568050'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9984',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '990510'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AS9202WD',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 210W / 소비전력: 590W / 2023년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 디스플레이표시 / 배터리잔량표시 / 헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '457000'],
#  ['LG전자 코드제로 A9 A912PM',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 160W / [구성] 스탠드거치 / 브러쉬: 바닥 / [배터리] 사용시간: 50분(최대) / 충전시간: 4시간 / 분리형(1개) / 색상: 블라썸핑크',
#   '250470'],
#  ['삼성전자 비스포크 슬림 VS15A680AEG',
#   '스틱청소기 / 무선 / 흡입형 / 흡입력: 150W / 소비전력: 450W / 2021년형 / [구성] 브러쉬: 바닥 / 물걸레: 별매 / 틈새 / [배터리] 사용시간: 50분(최대) / 충전시간: 4시간 / 내장형 / 리튬이온 / 2200mAh / 21.6V / [청소] 싸이클론흡입 / 디지털인버터모터 / 먼지통: 0.3L / [부가] 스마트폰제어 / 셀프스탠딩 / 먼지필터 / 5단계여과 / 색상: 페블그레이 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1143x194mm',
#   '291840'],
#  ['드리미 V11',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 150AW / 흡입력: 25000Pa / 소비전력: 450W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 1시간30분(최대) / 충전시간: 4시간 / 3000mAh / 25.2V / [청소] 싸이클론흡입 / BLDC모터 / 먼지통: 0.5L / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 레드 / 무게: 1.6kg / 크기(가로x세로): 202x1226mm',
#   '185060'],
#  ['삼성전자 비스포크 제트 AI VS25C970DW',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 250W / 2023년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 먼지감지센서 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새틴베이지 / 크기(가로x세로x깊이): 250x942x243mm / 출시가: 1,290,900원',
#   '675550'],
#  ['JONR ED12',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 9000Pa / 스탠드거치 / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 2600mAh / 물통: 정수: 0.85L, 오수: 0.4L / 오토클리닝 / 무게: 3.63kg',
#   '165880'],
#  ['DIBEA ALLNEW29000 PLUS',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 167AW / 흡입력: 40000Pa / 소비전력: 500W / 2023년형 / [구성] 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 카펫 / 연장관 / [배터리] 사용시간: 50분(최대) / 충전시간: 5시간 / 분리형(1개) / 리튬이온 / 2500mAh / 25.9V / [청소] LED라이트 / UV살균 / BLDC모터 / 먼지통: 0.68L / [부가] 디스플레이표시 / 배터리잔량표시 / 헤파필터 / 6단계여과 / 색상: 화이트 / 무게: 2.5kg / 분리형먼지통 / 크기(가로x세로x깊이): 245x1050~1275x210mm',
#   '236550'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9272WD',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '612120'],
#  ['샤크 에보 파워 플러스 WV250KR2',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 120W / 2019년형 / [구성] 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 12분(최대) / 충전시간: 2시간30분 / 분리형(1개) / 리튬이온 / 10.8V / BLDC모터 / [부가] 먼지필터 / 색상: 블랙 / 무게: 0.624kg / 크기(가로x세로x깊이): 61x419x53mm',
#   '149580'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9888',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 280W / 소비전력: 677W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '1044900'],
#  ['다이슨 싸이클론 V10',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 151AW / [구성] 충전 / 벽걸이거치 / 브러쉬: 바닥 / 펫 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 리튬이온 / [청소] 싸이클론흡입 / 디지털모터 / 먼지통: 0.5L / [부가] 프리볼트 / 헤파필터 / 색상: 레드 / 무게: 2.5kg / 크기(가로x세로x깊이): 242x1238x250mm',
#   '439660'],
#  ['다이슨 V15 디텍트 컴플리트',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 240AW / 2021년형 / [구성] 벽걸이거치 / 브러쉬: 레이저바닥, 바닥+카펫 / 펫 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간30분 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 먼지통: 0.54L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 골드/니켈 / 무게: 3kg / 크기(가로x세로x깊이): 250x1086x250mm',
#   '802370'],
#  ['삼성전자 비스포크 제트 AI VS28C973DR',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 280W / 2023년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간20분(최대) / 충전시간: 5시간 / 분리형(2개) / 리튬이온 / 3970+2200mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 먼지감지센서 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새틴세이지그린 / 크기(가로x세로x깊이): 250x942x243mm / 출시가: 1,649,000원',
#   '942240'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AS9272WD',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '524880'],
#  ['삼성전자 비스포크 제트 VS20B956D5',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 220W / 2022년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 산토리니베이지 / 크기(가로x세로x깊이): 250x930x202mm',
#   '568990'],
#  ['테팔 에어포스 라이트 TY6545KL',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2018년형 / [구성] 브러쉬: 바닥 / [배터리] 사용시간: 30분(최대) / 충전시간: 5시간 / 리튬이온 / 14.4V / [청소] 싸이클론흡입 / LED라이트 / 먼지통: 0.96L / [부가] 배터리잔량표시 / 셀프스탠딩 / 헤파필터 / 색상: 블랙 / 무게: 2.31kg / 크기(가로x세로x깊이): 260x1092x220 mm',
#   '113000'],
#  ['다이슨 V8',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 115AW / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3.5시간 / 리튬이온 / 싸이클론흡입 / [부가] 먼지필터 / 무게: 2.5kg / 크기(가로x세로x깊이): 221x1256x250mm',
#   '383880'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9402WD',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '600790'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9674',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '788430'],
#  ['로보락 다이애드 프로 콤보',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 17000Pa / 2024년형 / 스탠드거치 / 사용시간: 43분(최대) / 물통: 0.95L, 오수통 0.77L / 스마트폰제어 / 오토클리닝 / 오토드라이 / 무게: 4.8kg / 투에지클리닝 / 오염감지센서 / 브러쉬: 카펫, 침구, 틈새, 더스트, 바닥 / 크기(가로x세로x깊이): 270x1112x191mm',
#   '698990'],
#  ['로보락 다이애드 프로',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 17000Pa / 2023년형 / 스탠드거치 / 사용시간: 43분(최대) / 물통: 0.9L, 오수통 0.77L / 스마트폰제어 / 오토클리닝 / 오토드라이 / 무게: 4.8kg / 투에지클리닝 / 오염감지센서 / 크기(가로x세로x깊이): 270x1112x191mm',
#   '538020'],
#  ['삼성전자 비스포크 제트 AI VS25C972DR',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 250W / 2023년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(2개) / 리튬이온 / 2200+2200mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 먼지감지센서 / 디지털인버터모터 / 먼지통: 0.5L / 물통: 0.15L / [부가] 스마트폰제어 / 대화형알림창 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새틴베이지 / 크기(가로x세로x깊이): 250x942x243mm / 출시가: 1,449,000원',
#   '724240'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9472WD',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '691060'],
#  ['LG전자 코드제로 A9 AT9100SA',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 200W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 40분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 딥그레이(올인원타워), 판타지실버(청소기) / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '496490'],
#  ['일렉트로룩스 Well Q8 WQ81-3BSWF',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2023년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 53분(최대) / 리튬이온 / 2000mAh / [청소] 싸이클론흡입 / LED라이트 / [부가] 헤파필터 / 무게: 2.8kg / 크기(가로x세로x깊이): 258x1105x140mm',
#   '264220'],
#  ['샤오미 디어마 VC03S',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 15000Pa / 소비전력: 600W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 40분(최대) / 충전시간: 6시간 / 4000mAh / 먼지통: 0.6L / [부가] 헤파필터 / 색상: 화이트 / 무게: 1.2kg / 크기(가로x세로x깊이): 210x1155x180mm',
#   '99000'],
#  ['다이슨 V12 오리진 컴플리트',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 130AW / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 침구 / 펫 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 하이퍼미디움 / 먼지통: 0.35L / [부가] 디스플레이표시 / 헤파필터 / 색상: 니켈/퍼플 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1264x252mm',
#   '561920'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AU9872',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2022년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 36초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.7kg / 크기(가로x세로x깊이): 300x1120x260mm',
#   '783520'],
#  ['드리미 V10',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 140AW / 흡입력: 22000Pa / 소비전력: 450W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 2500mAh / 25.2V / 싸이클론흡입 / BLDC모터 / 먼지통: 0.5L / [부가] 헤파필터 / 5단계여과 / 색상: 화이트 / 무게: 1.5kg',
#   '116170'],
#  ['일렉트로룩스 얼티밋홈 900 EFP91814',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 150W / 2021년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 물걸레: 별매 / 펫 / 솔형 / 틈새 / 각도조절툴 / [배터리] 사용시간: 1시간(최대) / 충전시간: 1시간38분 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 인버터모터 / 먼지통: 0.4L / [부가] 디스플레이표시 / 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 어반그레이 / 무게: 2.88kg / 크기(가로x세로x깊이): 260x1120x260mm',
#   '369000'],
#  ['아이닉 i30 아이타워',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 35000Pa / 2023년형 / [구성] 먼지비움 / 충전 / 스탠드거치 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 1.5L / [배터리] 사용시간: 50분(최대) / 분리형(1개) / 리튬이온 / 2200mAh / [청소] LED라이트 / UV살균 / 먼지감지센서 / BLDC모터 / 먼지통: 0.4L / [부가] 디스플레이표시 / 헤파필터 / 2단계여과 / 무게: 2.5kg / 크기(가로x세로x깊이): 313x628x143mm',
#   '298000'],
#  ['무궁화전자 바로바로 MC-B250',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 60W / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 틈새 / 연장관 / [배터리] 사용시간: 20분(최대) / 충전시간: 8시간 / 니켈수소 / 10.8V / [부가] 먼지필터 / 무게: 1.3kg / 크기(가로x세로x깊이): 144x387x136mm',
#   '41000'],
#  ['보만 VC7210',
#   '핸디스틱청소기 / 무선 / 흡입형 / [구성] 브러쉬: 바닥 / 틈새 / 연장관 / [배터리] 사용시간: 10~15분(최대) / 충전시간: 10시간 / 1.2V / [부가] 워셔블먼지필터 / 색상: 블랙+오렌지 / 무게: 0.8kg / 크기(가로x세로x깊이): 145x440x115mm',
#   '47900'],
#  ['샤오미 COCLEAN V30',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 155AW / 흡입력: 25000Pa / 소비전력: 400W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간30뷴 / 분리형(1개) / 2000mAh / [청소] LED라이트 / BLDC모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 3단계여과 / 색상: 그린 / 무게: 1.27kg / 크기(가로x세로x깊이): 250x1150x220mm',
#   '112610'],
#  ['삼성전자 비스포크 제트 VS20B956BUE',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / 2022년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 산토리니베이지 / 크기(가로x세로x깊이): 250x930x202mm',
#   '495560'],
#  ['비쎌(BISSELL) 크로스웨이브 3.0 PRO 2765Z',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 스탠드거치 / 사용시간: 30분(최대) / 물통: 정수: 0.828L, 오수: 0.55L / 배터리잔량표시 / 오토클리닝 / 크기(가로x세로x깊이): 265x1125x65mm',
#   '112890'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9874',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '935830'],
#  ['일렉트로룩스 WELL Q6 WQ61-1OGG',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2020년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 45분(최대) / 충전시간: 4시간30분 / 내장형 / 리튬이온 / 18V / [청소] 싸이클론흡입 / LED라이트 / 먼지통: 0.3L / [부가] 배터리잔량표시 / 셀프스탠딩 / 먼지필터 / 5단계여과 / 색상: 그라나이트그레이 / 무게: 2.65kg / 크기(가로x세로x깊이): 386x692x146mm',
#   '276480'],
#  ['삼성전자 파워스틱 VS02R6512JG',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 120W / 2021년형 / [구성] 브러쉬: 바닥 / 틈새 / [배터리] 분리형(1개) / 리튬이온 / [청소] 먼지통: 0.25L / [부가] 셀프스탠딩 / 먼지필터 / 색상: 뉴트럴그레이 / 무게: 2.7kg / 크기(가로x세로x깊이): 250x1130x225mm',
#   '209850'],
#  ['신일전자 SVC-K720TW',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 22000Pa / 소비전력: 40W / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 틈새 / 연장관 / [배터리] 사용시간: 18분(최대) / 충전시간: 6시간 30분 / 리튬이온 / 2180mAh / BLDC모터 / [부가] 헤파필터 / 색상: 화이트 / 무게: 947g',
#   '40560'],
#  ['삼성전자 제트 VS20T92K3QD',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 200W / 소비전력: 550W / 2022년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 21.9V / [청소] 싸이클론흡입 / 인버터모터 / 먼지통: 0.6L / [부가] 디스플레이표시 / 프리볼트 / 워셔블헤파필터 / 5단계여과 / 색상: 티탄/그레이 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm',
#   '412960'],
#  ['다이슨 V12 디텍트 슬림',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 140AW / 2023년형 / [구성] 스탠드거치 / 브러쉬: 레이저바닥 / 솔형 / 틈새 / 카펫 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 먼지통: 0.35L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 골드/골드 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1264x252mm',
#   '740160'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9804',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '871120'],
#  ['아이룸 AST-009 플러스',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 12000Pa / 소비전력: 160W / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / 연장관 / 사용시간: 40분(최대) / 충전시간: 4시간 / 2200mAh / 22.2V / [청소] 싸이클론흡입 / LED라이트 / [부가] 배터리잔량표시 / 워셔블헤파필터 / 색상: 퍼플 / 무게: 1.89kg',
#   '108000'],
#  ['보쉬 GAS18V-1',
#   '핸디스틱청소기 / 무선 / 흡입형 / [구성] 브러쉬: 바닥 / 틈새 / 연장관 / 사용시간: 42분(최대) / 18V / 싸이클론흡입 / [부가] 먼지필터 / 2단계여과 / 색상: 블랙 / 무게: 1.3kg',
#   '70880'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AU9672WD',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2022년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 36초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.7kg / 크기(가로x세로x깊이): 300x1120x260mm',
#   '783640'],
#  ['앱코 오엘라 네오스핀 OBC-AW09',
#   '욕실청소기 / 무선 / 전동회전 / 회전속도: 220RPM / 소비전력: 8W / 2020년형 / [배터리] 사용시간: 50분(최대) / 충전시간: 4~5시간 / 리튬이온 / 1950mAh / 3.7V / [부가] 생활방수 / USB충전 / 색상: 화이트 / 무게: 0.86kg / 브러쉬: 원형, 평면, 틈새',
#   '40860'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AT9201WB',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 210W / 소비전력: 590W / 2021년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 스마트폰제어 / 디스플레이표시 / 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '576500'],
#  ['아이닉 NEW i20 (23년형)',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 35000Pa / 소비전력: 350W / 2023년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / [배터리] 사용시간: 50분(최대) / 충전시간: 5시간 / 분리형(1개) / 리튬이온 / 2200mAh / [청소] LED라이트 / UV살균 / BLDC모터 / 먼지통: 0.5L / [부가] 배터리잔량표시 / 헤파필터 / 5단계여과 / 색상: 블랙 / 무게: 1.5kg(본체기준) / 크기(가로x세로x깊이): 250x1150x210mm',
#   '198000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9974WE',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 연장관 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm',
#   '1258770'],
#  ['샤크 에보 파워시스템 ADV CS601',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2023년형 / [구성] 브러쉬: 바닥 / 침구 / 펫 / 틈새 / [배터리] 사용시간: 60분(최대) / 충전시간: 3시간30분 / 리튬이온 / 3000mAh / BLDC모터 / [부가] 먼지필터 / 색상: 블루, 오렌지 / 무게: 2kg / 크기(가로x세로x깊이): 476x1057x205mm',
#   '335610'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9888WE + M9 MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 280W / 소비전력: 677W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '2613990'],
#  ['비트로캔디 VC1003',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 23000Pa / 소비전력: 200W / 2024년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 32분(최대) / 충전시간: 4시간30분 / 2200mAh / [청소] BLDC모터 / [부가] 디스플레이표시 / 워셔블헤파필터',
#   '1562400'],
#  ['다이슨 V12s 디텍트 슬림 서브마린 컴플리트 (골드/골드)',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 140AW / 2023년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 레이저바닥 / 물걸레: 일반 / 펫 / 솔형 / 틈새 / 카펫 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / [청소] 먼지감지센서 / 먼지통: 0.35L / 물통: 정수: 0.3L, 오수: 0.36L / [부가] 디스플레이표시 / 배터리잔량표시 / 헤파필터 / 색상: 골드/골드 / 무게: 2.2kg / 크기(가로x세로x깊이): 257x1247x253mm',
#   '966930'],
#  ['JONR VC10 PRO',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 170AW / 흡입력: 27000Pa / 소비전력: 20W / 2023년형 / [구성] 먼지비움 / 충전 / 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 내장형 / 2500mAh / [청소] LED라이트 / 먼지통: 0.6L / [부가] 먼지필터 / 5단계여과 / 색상: 화이트 / 무게: 2.9kg',
#   '179000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9984TE + M9 MO971WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 에센스그라파이트 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '1867470'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9984WE + MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '1860630'],
#  ['삼성전자 비스포크 제트 AI VS28C973IS',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 280W / 2023년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 고온 / 침구 / 솔형 / 틈새 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간40분(최대) / 충전시간: 5시간 / 분리형(2개) / 리튬이온 / 2200+3970mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 먼지감지센서 / 디지털인버터모터 / 먼지통: 0.5L / 물통: 0.15L / [부가] 스마트폰제어 / 대화형알림창 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새틴베이지 / 무게: 2.88kg / 크기(가로x세로x깊이): 350x1091x300mm / 출시가: 1,749,000원',
#   '1036940'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AT9201WC',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 210W / 소비전력: 590W / 2022년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 스마트폰제어 / 디스플레이표시 / 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '690000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AU9602WD',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / 소비전력: 590W / 2022년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 36초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.7kg / 크기(가로x세로x깊이): 300x1120x260mm',
#   '765160'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9984GE + M9 MO972GA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍그린 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '1860630'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9402WD + MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입형 / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm / ※ 상품 옵션 확인 후 구매',
#   '1863990'],
#  ['삼성전자 비스포크 제트 AI VS28C973ES',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 280W / 2023년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간20분(최대) / 충전시간: 5시간 / 분리형(2개) / 리튬이온 / 3970+2200mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 먼지감지센서 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새블랙 / 크기(가로x세로x깊이): 250x942x243mm / 출시가: 1,540,900원',
#   '925970'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9572WD + M9 MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm / ※ 상품 옵션 확인 후 구매',
#   '2113990'],
#  ['다이슨 V12 디텍트 슬림 컴플리트 (골드)',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 150AW / 2021년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 레이저바닥 / 침구 / 펫 / 솔형 / 틈새 / 카펫 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 먼지통: 0.35L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 골드/골드 / 무게: 2.2kg / 크기(가로x세로x깊이): 250x1264x252mm',
#   '837790'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9984WE + M9 MO972WA + R9 RO965WB',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '4004000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9974WE + MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 연장관 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '2313990'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9804WE + M9 MO972WA',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입형 / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '2063990'],
#  ['다이슨 V15s 디텍트 슬림 서브마린 (옐로우/니켈)',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 240AW / 2024년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 레이저바닥 / 물걸레: 일반 / 펫 / 솔형 / 틈새 / 카펫 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간30분 / 분리형(1개) / [청소] 먼지감지센서 / 먼지통: 0.54L / 물통: 0.3L / [부가] 디스플레이표시 / 배터리잔량표시 / 헤파필터 / 색상: 옐로우/니켈 / 무게: 3kg / 크기(가로x세로x깊이): 253x1246x268mm',
#   '1244030'],
#  ['다이슨 디지털 슬림',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 100AW / 2020년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 미니바닥 / [배터리] 사용시간: 40분(최대) / 충전시간: 3시간30분 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지통: 0.3L / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 니켈 / 크기(가로x세로x깊이): 250x1100x250mm',
#   '449420'],
#  ['테팔 에어포스 라이트 TY6541KM',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2018년형 / [구성] 브러쉬: 바닥 / [배터리] 사용시간: 30분(최대) / 충전시간: 5시간 / 리튬이온 / 14.4V / [청소] 싸이클론흡입 / LED라이트 / [부가] 배터리잔량표시 / 셀프스탠딩 / 먼지필터 / 색상: 퍼플 / 무게: 2.31kg',
#   '121550'],
#  ['LG전자 코드제로 A9 AT9170IA',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 200W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 일반 / 솔형 / 틈새 / [배터리] 사용시간: 40분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 스마트인버터모터 / [부가] 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 아이언그레이+딥그레이 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '664400'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9884GE + M9 MO972GA + R9 RO965GB',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍그린 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '4004000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9604WE + 에어로퍼니처(원형) AS062PWHAR',
#   '핸디스틱청소기+공기청정기세트 / 무선 / 흡입형 / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] LED라이트 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '1390000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9888WE + M9 MO972WA +R9 RO965WB',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 280W / 소비전력: 677W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '4204000'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9804WE + M9 MO972WA + R9 RO965WB',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입형 / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '3654000'],
#  ['삼성전자 비스포크 제트 VS20B957F5',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 220W / 2022년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 펫 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(2개) / 리튬이온 / 2200+2200mAh / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 산토리니베이지 / 크기(가로x세로x깊이): 250x930x202mm',
#   '760250'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AX9884TE + M9 MO972WA + R9 RO965WB',
#   '핸디스틱청소기+로봇청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 에센스그라파이트 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm / ※ 상품 옵션 확인 후 구매',
#   '4004000'],
#  ['삼성전자 비스포크 제트 VS20B957E5',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 220W / 2022년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(2개) / 리튬이온 / 2200+2200mAh / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 산토리니베이지 / 크기(가로x세로x깊이): 250x930x202mm',
#   '630520'],
#  ['JONR ED11',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 9000Pa / 스탠드거치 / 충전시간: 4시간 / 2600mAh / 물통: 정수: 0.85L, 오수: 0.45L / 오토클리닝 / 오토드라이 / 무게: 3.35kg',
#   '125560'],
#  ['플러스마이너스제로 G040 Ver.4',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2023년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 틈새 / [배터리] 사용시간: 57분(최대) / 분리형(1개) / 리튬이온 / BLDC모터 / [부가] 워셔블먼지필터 / 2단계여과 / 색상: 화이트, 네이비그레이, 그린 / 크기(가로x세로x깊이): 134x407x100mm',
#   '289000'],
#  ['LG전자 오브제컬렉션 코드제로 A9 AU9572WD',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 60초 / 브러쉬: 바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1120x260mm',
#   '900000'],
#  ['JONR ED20 PRO',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 17000Pa / 2024년형 / 스탠드거치 / 사용시간: 1시간(최대) / BLDC모터 / 먼지통: 350mL / 물통: 정수: 550mL, 오수: 650mL / 디스플레이표시 / 오토클리닝 / 색상: 화이트 / 무게: 4.4kg / 오토무빙',
#   '226490'],
#  ['캐치웰 TW100 매직타워',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 370W / 2023년형 / [구성] 먼지비움 / 충전 / 스탠드거치 / 먼지비움시간: 20초 / 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / 카펫 / 먼지봉투: 3L / [배터리] 사용시간: 1시간(최대) / 충전시간: 6시간 / 분리형(1개) / 2500mAh / [청소] 싸이클론흡입 / LED라이트 / BLDC모터 / 먼지통: 0.5L / [부가] 헤파필터 / 색상: 화이트 / 먼지봉투용량: 3L',
#   '289000'],
#  ['다이슨 V10 플러피 오리진',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 151AW / 2021년형 / [구성] 충전 / 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 미니바닥 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 싸이클론흡입 / 먼지통: 0.5L / [부가] 먼지필터 / 색상: 레드 / 무게: 2.5kg / 크기(가로x세로x깊이): 256x1241x250mm',
#   '448970'],
#  ['삼성전자 비스포크 제트 VS20C954AQB',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 210W / 2024년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / [청소] 싸이클론흡입 / LED라이트 / 디지털인버터모터 / 먼지통: 0.8L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 미드나잇블루 / 크기(가로x세로x깊이): 250x930x53mm',
#   '429000'],
#  ['다이슨 V15 오리진 컴플리트',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 200AW / 2023년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 펫 / 솔형 / 틈새 / 카펫 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간30분 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 먼지통: 0.54L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 니켈/레드 / 무게: 3kg / 크기(가로x세로x깊이): 266x1260x250mm',
#   '652500'],
#  ['LG전자 오브제컬렉션 코드제로 A9S AU9882',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 220W / 소비전력: 590W / 2022년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / 액서서리수납 / 스탠드거치 / 먼지비움시간: 36초 / 브러쉬: 와이드바닥 / 물걸레: 스팀 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 디스플레이표시 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.7kg / 크기(가로x세로x깊이): 300x1120x260mm',
#   '633180'],
#  ['샤오미 Shunzao H100 Pro',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 12000Pa / 소비전력: 220W / 2023년형 / 사용시간: 35분(최대) / 충전시간: 4시간 / 리튬이온 / 물통: 스테이션: 3L+ 오수: 0.78L / 배터리잔량표시 / 오토드라이 / 헤파필터 / 색상: 화이트 / 크기(가로x세로x깊이): 270x1100x270mm',
#   '245790'],
#  ['다이슨 마이크로 1.5kg SV21',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2021년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 솔형 / 미니바닥 / [배터리] 사용시간: 20분(최대) / 충전시간: 3시간30분 / 분리형(1개) / 싸이클론흡입 / 먼지통: 0.2L / [부가] 먼지필터 / 5단계여과 / 색상: 니켈 / 무게: 1.5kg / 크기(가로x세로x깊이): 225x1103x207mm',
#   '482640'],
#  ['DIBEA 올인원 컴팩트',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 23000Pa / 소비전력: 260W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 침구 / 틈새 / [배터리] 사용시간: 50분(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2600mAh / 18.5V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / BLDC모터 / 먼지통: 0.46L / [부가] 디스플레이표시 / 먼지필터 / 4단계여과 / 색상: 레드 / 무게: 0.93kg / 크기(가로x세로x깊이): 245x990x185mm',
#   '139000'],
#  ['삼성전자 Jet 60 Flex',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2024년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 40분(최대) / [청소] 싸이클론흡입 / [부가] 5단계여과',
#   '225760'],
#  ['샤오미 디어마 DEM-T30W',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 23000Pa / 소비전력: 240W / 2023년형 / [구성] 벽걸이거치 / 브러쉬: 레이저바닥 / 솔형 / 틈새 / [배터리] 사용시간: 45분(최대) / 충전시간: 5시간30분 / 내장형 / 2500mAh / 26V / [청소] 싸이클론흡입 / BLDC모터 / 먼지통: 0.56L / [부가] 색상: 블랙 / 크기(가로x세로x깊이): 256x1275x280mm',
#   '99800'],
#  ['테팔 엑스퍼트 3.60 TY6974',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2020년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / [배터리] 사용시간: 45분(최대) / 충전시간: 5시간 / 분리형(1개) / 리튬이온 / 22V / [청소] 싸이클론흡입 / LED라이트 / DC모터 / 먼지통: 0.5L / [부가] 배터리잔량표시 / 프리볼트 / 워셔블먼지필터 / 색상: 블랙+옐로우 / 무게: 2.2kg',
#   '161050'],
#  ['신일전자 SVC-BS06KP',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 120W / 흡입력: 10000Pa / 2024년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 12000mAh / [청소] LED라이트 / [부가] 배터리잔량표시 / 먼지필터 / 색상: 블랙 / 무게: 1.9kg / 크기(가로x세로x깊이): 240x1060x110mm',
#   '107780'],
#  ['DIBEA ALLNEW22000 (22년형)',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 35000Pa / 소비전력: 280W / 2022년형 / [구성] 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 40분(최대) / 충전시간: 4~5시간 / 내장형 / 리튬이온 / 2200mAh / 22.2V / [청소] 싸이클론흡입 / LED라이트 / UV살균 / BLDC모터 / 먼지통: 0.55L / [부가] 배터리잔량표시 / 워셔블헤파필터 / 4단계여과 / 색상: 스노우화이트 / 무게: 2.1kg / 크기(가로x세로x깊이): 245x1040x212mm',
#   '189050'],
#  ['삼성전자 비스포크 제트 VS30D973HR',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 310W / 2024년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 싸이클론비움 / 충전 / UVC LED / 스탠드거치 / 먼지비움시간: 14초 / 브러쉬: 바닥 / 물걸레: 고온 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간20분(대용량배터리기준)(최대) / 충전시간: 5시간(대용량배터리기준) / 분리형(2개) / 리튬이온 / 3970mAh / 25.2V / [청소] 싸이클론흡입 / AI청소 / LED라이트 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / 물통: 0.15L / [부가] 스마트폰제어 / 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 항균물통 / 워셔블헤파필터 / 5단계여과 / 색상: 새틴차콜 / 크기(가로x세로x깊이): 350x1091x300mm',
#   '1512471'],
#  ['다이슨 옴니 글라이드',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 50AW / 2020년형 / [구성] 벽걸이거치 / 브러쉬: 전방향바닥 / 솔형 / 미니바닥 / 연장관 / [배터리] 사용시간: 20분(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 싸이클론흡입 / 먼지통: 0.2L / [부가] 워셔블헤파필터 / 5단계여과 / 색상: 퍼플 / 무게: 1.9kg / 버튼식 / 크기(가로x세로x깊이): 208x1077x92mm',
#   '388350'],
#  ['캐치웰 CV6 PLUS',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 12000Pa / 소비전력: 160W / [구성] 충전 / 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 40분(최대) / 충전시간: 4시간 / 리튬이온 / 22.2V / 싸이클론흡입 / LED라이트 / 먼지통: 0.35L / [부가] 워셔블헤파필터 / 색상: 레드 / 무게: 1.89kg',
#   '79000'],
#  ['아이룸 윈드포스 F9',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 350W / 흡입력: 42000Pa / 2023년형 / [구성] 브러쉬: 바닥 / 물걸레: 별매 / 침구 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 40분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / 2200mAh / LED라이트 / BLDC모터 / 먼지통: 600mL / 물통: 160mL / [부가] 디스플레이표시 / 먼지필터 / 5단계여과 / 색상: 화이트 / 무게: 2.3kg',
#   '178000'],
#  ['기펠 ZET-10',
#   '핸디스틱청소기 / 무선 / 흡입형 / 소비전력: 200W / [구성] 브러쉬: 바닥 / 솔형 / 틈새 / BLDC모터 / [부가] 먼지필터 / 색상: 그레이/실버 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x1045x240mm',
#   '234740'],
#  ['LG전자 코드제로 A9 Air AS9000WR',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 150W / 소비전력: 450W / 2024년형 / [구성] 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 틈새(내장형) / [배터리] 사용시간: 40분(최대) / 충전시간: 4시간 / 분리형(1개) / 리튬이온 / [청소] 스마트인버터모터 / [부가] 배터리잔량표시 / 색상: 카밍베이지 / 무게: 1.97kg / 크기(가로x세로x깊이): 251x1026x242mm',
#   '567010'],
#  ['일렉트로룩스 WELL Q6 WQ61-1EDB',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2021년형 / [구성] 충전 / 스탠드거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 45분(최대) / 충전시간: 4시간30분 / 내장형 / 리튬이온 / 18V / [청소] 싸이클론흡입 / LED라이트 / 먼지통: 0.3L / [부가] 배터리잔량표시 / 셀프스탠딩 / 먼지필터 / 5단계여과 / 색상: 데님블루 / 무게: 2.65kg / 크기(가로x세로x깊이): 258x1105x140mm',
#   '283900'],
#  ['비트로캔디 VC903MF',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 20000Pa / 소비전력: 200W / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / 패브릭 / 연장관 / [배터리] 사용시간: 50분(최대) / 충전시간: 4시간30분 / 내장형 / 리튬이온 / 2200mAh / 22.2V / [청소] 싸이클론흡입 / 인버터모터 / 먼지통: 0.8L / [부가] 프리볼트 / 헤파필터 / 색상: 옐로우/골드 / 무게: 1.4kg',
#   '1279900'],
#  ['샤크 IQ+ IW3241KR',
#   '핸디스틱청소기 / 무선 / 흡입형 / 2023년형 / [구성] 먼지비움 / 스탠드거치 / 침구 / 펫 / 틈새 / 미니바닥 / [배터리] 사용시간: 42분(최대) / 충전시간: 4시간 / 리튬이온 / 3000mAh / 14.8V / [청소] LED라이트 / 먼지감지센서 / 인버터모터 / [부가] 디스플레이표시 / 먼지필터 / 색상: 라이트그레이 / 무게: 2.2kg',
#   '846000'],
#  ['삼성전자 비스포크 제트 VS20A957E3',
#   '핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 210W / 2021년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / 스탠드거치 / 먼지비움시간: 20초 / 브러쉬: 바닥 / 물걸레: 일반 / 침구 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(2개) / 리튬이온 / 2200+2200mAh / 25.2V / [청소] 싸이클론흡입 / 자동물공급 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 미스티화이트 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x930x202mm',
#   '594140'],
#  ['삼성전자 비스포크 제트 VS20A956A3',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 210W / 2021년형 / [구성] 거치대: 청정스테이션 / 먼지비움 / 충전 / 스탠드거치 / 먼지비움시간: 20초 / 브러쉬: 바닥 / 물걸레: 별매 / 솔형 / 틈새 / 연장관 / 먼지봉투: 1.2L / [배터리] 사용시간: 1시간(최대) / 충전시간: 3시간30분 / 분리형(1개) / 리튬이온 / 2200mAh / 25.2V / [청소] 싸이클론흡입 / 물분사 / 디지털인버터모터 / 먼지통: 0.5L / [부가] 대화형알림창 / 디스플레이표시 / 배터리잔량표시 / 워셔블헤파필터 / 5단계여과 / 색상: 미스티화이트 / 무게: 2.5kg / 크기(가로x세로x깊이): 250x930x202mm / 출시가: 1,150,000원',
#   '500570'],
#  ['비즈포비즈 클래파 BVC-H10',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 6000Pa / 소비전력: 45W / 2020년형 / [구성] 브러쉬: 바닥 / 솔형 / 틈새 / 연장관 / [배터리] 사용시간: 20분(최대) / 충전시간: 4시간 / 리튬이온 / 4000mAh / 7.4V / 싸이클론흡입 / DC모터 / 먼지통: 0.9L / [부가] USB충전 / 헤파필터 / 3단계여과 / 색상: 블루/네이비 / 무게: 0.9kg / 크기(가로x세로x깊이): 130x1130x70mm',
#   '38500'],
#  ['다이슨 V15 오리진 플러피',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 200AW / 2023년형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 솔형 / 틈새 / [배터리] 사용시간: 1시간(최대) / 충전시간: 4시간30분 / 분리형(1개) / [청소] 싸이클론흡입 / 먼지감지센서 / 하이퍼미디움모터 / 먼지통: 0.54L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 니켈/레드 / 무게: 3kg / 크기(가로x세로x깊이): 266x1260x250mm',
#   '636990'],
#  ['캐치웰 THC-1000',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 8000Pa / 소비전력: 75W / [구성] 스탠드거치 / 솔형 / 틈새 / [배터리] 사용시간: 28분(최대) / 충전시간: 4시간 / 2600mAh / 10.95V / [청소] 싸이클론흡입 / 먼지통: 0.15L / [부가] 프리볼트 / 헤파필터 / 색상: 아이언그레이, 엣지블랙, 스톤화이트 / 무게: 0.58kg',
#   '39900'],
#  ['마끼다 DCL180Z',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 30W / [배터리] 사용시간: 20분(최대) / 분리형(1개) / 리튬이온 / 18V / 먼지통: 0.65L / [부가] 먼지필터 / 색상: 블루/네이비 / 무게: 1.2kg',
#   '51920'],
#  ['삼성전자 비스포크 슬림 VS15A680DFW',
#   '스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 150W / 소비전력: 450W / 2021년형 / [구성] 브러쉬: 바닥 / 물걸레: 일반 / 틈새 / [배터리] 사용시간: 50분(최대) / 충전시간: 4시간 / 내장형 / 리튬이온 / 2200mAh / 21.6V / [청소] 싸이클론흡입 / 자동물공급 / 디지털인버터모터 / 먼지통: 0.3L / [부가] 스마트폰제어 / 셀프스탠딩 / 먼지필터 / 5단계여과 / 색상: 미스티화이트 / 무게: 2.6kg / 크기(가로x세로x깊이): 250x1143x194mm',
#   '368430'],
#  ['다이슨 Gen5 디텍트 컴플리트',
#   '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 262AW / 2022년형 / [구성] 스탠드거치 / 브러쉬: 레이저바닥 / 펫 / 틈새 / 미니바닥 / [배터리] 사용시간: 1시간10분(최대) / 충전시간: 4시간30 / 분리형(1개) / 리튬이온 / [청소] 싸이클론흡입 / 먼지감지센서 / 먼지통: 0.77L / [부가] 디스플레이표시 / 워셔블헤파필터 / 색상: 퍼플/퍼플 / 무게: 3.5kg / 크기(가로x세로x깊이): 276x1276x250mm',
#   '960300']]

# %% [markdown]
# ##### 여러페이지 크롤링 하는 방법
# - URL
#     - https://search.danawa.com/dsearch.php?query=무선청소기&originalQuery=무선청소기&previousKeyword=무선청소기&checkedInfo=N&volumeType=allvs&page=1&limit=120&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&mode=simple&isInitTireSmartFinder=N&recommendedSort=N&defaultUICategoryCode=10325109&defaultPhysicsCategoryCode=72%7C80%7C81%7C0&defaultVmTab=3138&defaultVaTab=1098867&isZeroPrice=Y&quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A

# %%
## 검색어, 페이지를 변경하면서 URL생성함수
def getSearchPageUrl(keyword, page):
    ecKeyword = parse.quote(keyword)
    url = f'https://search.danawa.com/dsearch.php?query={ecKeyword}&originalQuery={ecKeyword}&previousKeyword={ecKeyword}&checkedInfo=N&volumeType=allvs&' + \
          f'page={page}&limit=120&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&mode=simple&isInitTireSmartFinder=N&' + \
            'recommendedSort=N&defaultUICategoryCode=10325109&defaultPhysicsCategoryCode=72%7C80%7C81%7C0&defaultVmTab=3138&defaultVaTab=1098867&isZeroPrice=Y&' + \
            'quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A'
    return url

# %%
## 상품정보 추출하는 함수
def getProdItems(prodItems):    
    prodData = []

    for prodItem in prodItems:
        try:
            prodName = prodItem.select('p.prod_name > a')[0].text.strip()   # 상품명 가져오기
            specList = prodItem.select('div.spec_list')[0].text.strip().replace('\t', '')   # 상품 스팩목록 가져오기
            price = prodItem.select('input')[1].get('value') # 최저가 가져오기
            prodData.append([prodName, specList, price])
        except:
            pass
    
    return prodData

# %%
# 검색어에 ' '가 있으면 URL에서 링크 클릭이 안되는 문제 발생
getSearchPageUrl('마이크로 sd카드', 5)
# Out:
# 'https://search.danawa.com/dsearch.php?query=%EB%A7%88%EC%9D%B4%ED%81%AC%EB%A1%9C%20sd%EC%B9%B4%EB%93%9C&originalQuery=%EB%A7%88%EC%9D%B4%ED%81%AC%EB%A1%9C%20sd%EC%B9%B4%EB%93%9C&previousKeyword=%EB%A7%88%EC%9D%B4%ED%81%AC%EB%A1%9C%20sd%EC%B9%B4%EB%93%9C&checkedInfo=N&volumeType=allvs&page=5&limit=120&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&mode=simple&isInitTireSmartFinder=N&recommendedSort=N&defaultUICategoryCode=10325109&defaultPhysicsCategoryCode=72%7C80%7C81%7C0&defaultVmTab=3138&defaultVaTab=1098867&isZeroPrice=Y&quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A'

# %%
total_page = 10

for page in tqdm(range(1, total_page+1)):
    # print('페이지 처리')    # tqdm 진행바가 여러번 출력
    time.sleep(1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:10<00:00,  1.00s/it]

# %%
## 여러페이지 검색 후 크롤링하는 작업
driver = webdriver.Chrome()
# 암묵적으로 웹 자원 로드를 위해 3초정도 대기
driver.implicitly_wait(3.0)

keyword = '무선청소기'
total_page = 20
prodDataTotal = []  # 최종적으로 저장할 리스트

for page in tqdm(range(11, total_page+1)):
    # 검색 페이지 이동
    url = getSearchPageUrl(keyword, page)
    driver.get(url)
    # 페이지 로딩이 완료될때까지 5초간 대기
    time.sleep(5)
    
    # 현재 페이지 html 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 상품정보 추출
    prodItems = soup.select('ul.product_list > li.prod_item')
    prodItemList = getProdItems(prodItems)  # 리스트로 추출하는 함수
    
    # 추출된 정보를 prodDataTotal 추가
    prodDataTotal += prodItemList
# Out:
# 100%|██████████| 10/10 [02:14<00:00, 13.45s/it]

# %%
dfprodData = pd.DataFrame(prodDataTotal)

# %%
dfprodData.columns = ['제품명', '제품스팩', '최저가']

# %%
dfprodData.to_excel('./data/다나와_무선청소기_결과2.xlsx', index=False)
